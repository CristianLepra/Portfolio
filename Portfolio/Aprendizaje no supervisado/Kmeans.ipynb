# %% [markdown]
# # Ejercicio 1
#
# En base a un set de datos sintéticos, aplicar el K-Means utilizando el algoritmo para el cálculo de cantidad estimada de clusters (gráfica de codo)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
# use seaborn plotting defaults
import seaborn as sns; sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
X, _ = make_blobs(n_samples=300,
                  random_state=0, cluster_std=6)
plt.scatter(X[:, 0], X[:, 1], s=50)

# %%
kmeans_kwargs = {
"init": "random",
"n_init": 10,
"random_state": 1,
}

#create list to hold SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

#visualize results
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
#Por defecto utiliza Kmeans++
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X) #TODO
y_kmeans = kmeans.predict(X) #TODO

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
ax[0].scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='rainbow')
#ax[0].set(xlabel='Red', ylabel='Green', xlim=(0, 1), ylim=(0, 1))

#Con otro parámetro
kmeansPlus = KMeans(n_clusters=4, random_state=0, max_iter=5)
kmeansPlus.fit(X) #TODO
y_kmeansPlus = kmeansPlus.predict(X) #TODO

ax[1].scatter(X[:, 0], X[:, 1], c=y_kmeansPlus, s=50, cmap='rainbow')
#ax[1].set(xlabel='Red', ylabel='Blue', xlim=(0, 1), ylim=(0, 1))
