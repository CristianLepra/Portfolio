# %% [markdown]
# # Data cleaning  Exercises

# %%
import pandas as pd
import numpy as np
import lxml
import os
import matplotlib.pyplot as plt

# %% [markdown]
# > El archivo es una pequeña muestra del dataset [wine-reviews](https://www.kaggle.com/datasets/zynicide/wine-reviews) que contiene información sobre reviews de vinos, incluyendo variedad, geolocalización, vinería, precio y descripción.

# %%
file = os.path.join('winemag-data_first150k.csv')

# %%
df = pd.read_csv(file,index_col=0)
df
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# * Las columnas `region_1` y `region_2` tienen nombres poco descriptivos, *renomblarlas* como `region` y `locate` respectivamente.

# %%
df.rename(columns= {'region_1':'region', 'region_2':'locate'} )
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province             region             locate  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# * Guardar el dataset en un archivo `Excel`

# %%
df.to_excel('Excelvino.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  object
#  1   description  150930 non-null  object
#  2   designation  105195 non-null  object
#  3   points       150930 non-null  int64
#  4   price        137235 non-null  float64
#  5   province     150925 non-null  object
#  6   region_1     125870 non-null  object
#  7   region_2     60953 non-null   object
#  8   variety      150930 non-null  object
#  9   winery       150930 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %% [markdown]
# * Completar la siguiente tabla:
#
# | Column name 	| Data classification 	|
# |------------:	|--------------------:	|
# |      Locate   |          object     	|
# |     Variety 	|          object     	|
# |      Points	|             int     	|
# |     Country 	| object 	|
# |       Price 	|         float64            	|
#
# > [herramienta online de generación de tablas en Markdown](https://www.tablesgenerator.com/markdown_tables#)

# %% [markdown]
# * Genera un grafico donde visualices variedad y precio

# %%
# son muchos datos 
fig = plt.figure()
ax = fig.subplots()
ax.bar(df['variety'].head, df['price'].head)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variety'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       2 fig = plt.figure()
#       3 ax = fig.subplots()
# ----> 4 ax.bar(df['variety'].head, df['price'].head)
#       5 plt.show()
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'variety'

# %% [markdown]
# ----

# %% [markdown]
# * Dado el siguiente DataFrame con algunos datos de visitas de perros al veterinario:

# %%
dogs_visits = {
    "date": {
        0: "2018-09-02",
        1: "2019-03-13",
        2: "2019-03-19",
        3: "2018-10-02",
        4: "2018-01-17",
        5: "2019-10-19",
        6: "2019-05-01",
        7: "2019-06-07",
        8: "2019-03-30",
        9: "2019-01-04",
        10: "2019-04-22",
        11: "2018-08-17",
        12: "2019-08-19",
        13: "2019-09-30",
        14: "2019-11-29",
    },
    "name": {
        0: "Bella",
        1: "Max",
        2: "Charlie",
        3: "Bella",
        4: "Stella",
        5: "Lucy",
        6: "Max",
        7: "Max",
        8: "Cooper",
        9: "Bernie",
        10: "Charlie",
        11: "Stella",
        12: "Charlie",
        13: "Cooper",
        14: "Lucy",
    },
    "breed": {
        0: "Labrador",
        1: "Chow Chow",
        2: "Poodle",
        3: "Labrador",
        4: "Chihuahua",
        5: "Chow Chow",
        6: "Chow Chow",
        7: "Labrador",
        8: "Schnauzer",
        9: "St. Bernard",
        10: "Poodle",
        11: "Labrador",
        12: "Chihuahua",
        13: "Chow Chow",
        14: "Chow Chow",
    },
    "weight_kg": {
        0: 24.87,
        1: 24.13,
        2: 24.95,
        3: 33.72,
        4: 1.51,
        5: 24.07,
        6: 31.25,
        7: 28.35,
        8: 16.91,
        9: 74.98,
        10: 25.37,
        11: 23.55,
        12: 2.95,
        13: 25.16,
        14: 24.19,
    },
}
df = pd.DataFrame(dogs_visits)

df
# Out:
#           date     name        breed  weight_kg
# 0   2018-09-02    Bella     Labrador      24.87
# 1   2019-03-13      Max    Chow Chow      24.13
# 2   2019-03-19  Charlie       Poodle      24.95
# 3   2018-10-02    Bella     Labrador      33.72
# 4   2018-01-17   Stella    Chihuahua       1.51
# 5   2019-10-19     Lucy    Chow Chow      24.07
# 6   2019-05-01      Max    Chow Chow      31.25
# 7   2019-06-07      Max     Labrador      28.35
# 8   2019-03-30   Cooper    Schnauzer      16.91
# 9   2019-01-04   Bernie  St. Bernard      74.98
# 10  2019-04-22  Charlie       Poodle      25.37
# 11  2018-08-17   Stella     Labrador      23.55
# 12  2019-08-19  Charlie    Chihuahua       2.95
# 13  2019-09-30   Cooper    Chow Chow      25.16
# 14  2019-11-29     Lucy    Chow Chow      24.19

# %% [markdown]
# * ¿Cómo está conformado el index?

# %%
df.set_index(['date'])
# Out:
#                name        breed  weight_kg
# date
# 2018-09-02    Bella     Labrador      24.87
# 2019-03-13      Max    Chow Chow      24.13
# 2019-03-19  Charlie       Poodle      24.95
# 2018-10-02    Bella     Labrador      33.72
# 2018-01-17   Stella    Chihuahua       1.51
# 2019-10-19     Lucy    Chow Chow      24.07
# 2019-05-01      Max    Chow Chow      31.25
# 2019-06-07      Max     Labrador      28.35
# 2019-03-30   Cooper    Schnauzer      16.91
# 2019-01-04   Bernie  St. Bernard      74.98
# 2019-04-22  Charlie       Poodle      25.37
# 2018-08-17   Stella     Labrador      23.55
# 2019-08-19  Charlie    Chihuahua       2.95
# 2019-09-30   Cooper    Chow Chow      25.16
# 2019-11-29     Lucy    Chow Chow      24.19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       15 non-null     object
#  1   name       15 non-null     object
#  2   breed      15 non-null     object
#  3   weight_kg  15 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 600.0+ bytes

# %% [markdown]
# * Completar la siguiente tabla
#
# |           	| data classification 	|
# |----------:	|--------------------:	|
# |      date 	|          objec        |
# |      name 	|          object       |
# |     breed 	|          object       |
# | weight_kg 	|          float64     	|

# %% [markdown]
# * Generar un DataFrame con **el último registro de cada perro**.
#     * A priori, ¿qué resultado se obtiene *"droppeando"* filas sin argumentos?
#     * ¿Droppeando según la columna `name`?
#     * ¿Qué columna o combinación de columnas hace único el registro de un perro?
#     * ¿Qué ocurrencia debe conformar el DataFrame final?

# %%
df.groupby(['name','breed'])['date'].max()
# Out:
# name     breed
# Bella    Labrador       2018-10-02
# Bernie   St. Bernard    2019-01-04
# Charlie  Chihuahua      2019-08-19
#          Poodle         2019-04-22
# Cooper   Chow Chow      2019-09-30
#          Schnauzer      2019-03-30
# Lucy     Chow Chow      2019-11-29
# Max      Chow Chow      2019-05-01
#          Labrador       2019-06-07
# Stella   Chihuahua      2018-01-17
#          Labrador       2018-08-17
# Name: date, dtype: object

# %%
df.isna().any()
# Out:
# date         False
# name         False
# breed        False
# weight_kg    False
# dtype: bool

# %% [markdown]
# * Dado el siguiente DataFrame con datos de diputados de Rumania:

# %%
df3=pd.read_html(
    "https://en.wikipedia.org/wiki/List_of_members_of_the_Chamber_of_Deputies_of_Romania_(2016%E2%80%932020)"
)[0]
df3
# Out:
#                 Deputy[1][2]             Party      Constituency
# 0       Florin Claudiu Roman               PNL              Alba
# 1       Olar Corneliu Răcuci               PNL              Alba
# 2             Claudiu Vasile               PNL              Alba
# 3                 Sorin Bumb               PNL              Alba
# 4                 Ioan Dîrzu               PSD              Alba
# ..                       ...               ...               ...
# 323  Giurgeci Slobodan Ghera  Minorities group  Minorities group
# 324              Ovidiu Ganț  Minorities group  Minorities group
# 325         Victoria Longher  Minorities group  Minorities group
# 326     Andi Gabriel Grosaru  Minorities group  Minorities group
# 327           Iulius Firczak  Minorities group  Minorities group
#
# [328 rows x 3 columns]

# %% [markdown]
# * Corregir los nombres de columnas

# %%
df3.rename(columns= {'Deputy[1][2]':'Deputy'} )
# Out:
#                       Deputy             Party      Constituency
# 0       Florin Claudiu Roman               PNL              Alba
# 1       Olar Corneliu Răcuci               PNL              Alba
# 2             Claudiu Vasile               PNL              Alba
# 3                 Sorin Bumb               PNL              Alba
# 4                 Ioan Dîrzu               PSD              Alba
# ..                       ...               ...               ...
# 323  Giurgeci Slobodan Ghera  Minorities group  Minorities group
# 324              Ovidiu Ganț  Minorities group  Minorities group
# 325         Victoria Longher  Minorities group  Minorities group
# 326     Andi Gabriel Grosaru  Minorities group  Minorities group
# 327           Iulius Firczak  Minorities group  Minorities group
#
# [328 rows x 3 columns]

# %% [markdown]
# * Generar una tabla con los column labels y su clasificación

# %% [markdown]
# |           	| data classification 	|
# |----------:	|--------------------:	|
# |     	Deputy 	|          object       |
# |     Party	    |          object       |
# |  Constituency	|          object       |

# %% [markdown]
# * Generar un DataFrame con el último diputado por partido

# %%
df4=df3.groupby(['Party'])['Deputy'].max()
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df4=df3.groupby(['Party'])['Deputy'].max()
#       2 df4
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
#    1767     raise ValueError(
#    1768         "Cannot subset columns with a tuple with more than one element. "
#    1769         "Use a list instead."
#    1770     )
# -> 1771 return super().__getitem__(key)
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Deputy'

# %% [markdown]
# ## is_null()
#
# Detecta datos faltantes en el DatFrame y devuelve un objeto similar con booleanos, donde `True` indica que en ese lugar hay un dato faltante.

# %%
df3.isnull().any()
# Out:
# Deputy[1][2]    False
# Party           False
# Constituency    False
# dtype: bool

# %% [markdown]
# ## NaN
#
# *Not a Number*. Cuando pandas no puede determinar un *valor numérico* para asignar a una entrada, le asigna `NaN`. Generalmente estos **NO AFECTAN** operaciones aritméticas.

# %%
df3.isna().any()
# Out:
# Deputy[1][2]    False
# Party           False
# Constituency    False
# dtype: bool

# %% [markdown]
# ## is_na()
#
# Detecta NaN en el DatFrame y devuelve un objeto similar con booleanos, donde `True` indica que en ese lugar hay un NaN.

# %%
df3.isna().any()

# %%
real_state = {
    "        PID": {
        0: "        100001000",
        1: "        100002000",
        2: "        100003000",
        3: "        100004000",
        4: "        ",
        5: "        100006000",
        6: "        100007000",
        7: "        100008000",
        8: "        100009000",
    },
    "ST_NUM": {
        0: 104,
        1: 197,
        2: np.nan,
        3: 201,
        4: 203,
        5: 207,
        6: np.nan,
        7: 213,
        8: 215,
    },
    "ST_NAME": {
        0: "PUTNAM",
        1: "LEXINGTON",
        2: "LEXINGTON",
        3: "BERKELEY",
        4: "BERKELEY",
        5: "BERKELEY",
        6: "WASHINGTON",
        7: "TREMONT",
        8: "TREMONT",
    },
    "OWN_OCCUPIED": {
        0: "Y",
        1: "N",
        2: "N",
        3: "12",
        4: "",
        5: "Y",
        6: np.nan,
        7: "Y",
        8: "Y",
    },
    "NUM_BEDROOMS": {
        0: "3",
        1: "3",
        2: "-1",
        3: "1",
        4: "3",
        5: "NAN",
        6: "2",
        7: "--",
        8: "na",
    },
    "NUM_BATH": {
        0: "1",
        1: "1.5",
        2: "1",
        3: np.nan,
        4: "2",
        5: "1",
        6: "HURLEY",
        7: "1",
        8: "2",
    },
    "SQ_FT": {
        0: "1000",
        1: "",
        2: "850",
        3: "700",
        4: "1600",
        5: "800",
        6: "950",
        7: np.nan,
        8: "1800",
    },
}

df = pd.DataFrame(real_state)
df
# Out:
#                  PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH  \
# 0          100001000   104.0      PUTNAM            Y            3        1
# 1          100002000   197.0   LEXINGTON            N            3      1.5
# 2          100003000     NaN   LEXINGTON            N           -1        1
# 3          100004000   201.0    BERKELEY           12            1      NaN
# 4                      203.0    BERKELEY                         3        2
# 5          100006000   207.0    BERKELEY            Y          NAN        1
# 6          100007000     NaN  WASHINGTON          NaN            2   HURLEY
# 7          100008000   213.0     TREMONT            Y           --        1
# 8          100009000   215.0     TREMONT            Y           na        2
#
#   SQ_FT
# 0  1000
# 1
# 2   850
# 3   700
# 4  1600
# 5   800
# 6   950
# 7   NaN
# 8  1800

# %% [markdown]
# > ST_NUM: Street number
# > ST_NAME: Street name
# > OWN_OCCUPIED: Is the residence owner occupied
# > NUM_BEDROOMS: Number of bedrooms

# %%
df.isna().any()
# Out:
#         PID     False
# ST_NUM           True
# ST_NAME         False
# OWN_OCCUPIED     True
# NUM_BEDROOMS    False
# NUM_BATH         True
# SQ_FT            True
# dtype: bool

# %% [markdown]
# * Corregir los nombres de columnas

# %%
df.rename(columns= {'ST_NUM':'Street number', 'ST_NAME':'Street name', 'OWN_OCCUPIED':'Is the residence owner occupied', 'NUM_BEDROOMS':'Number of bedrooms'} , inplace=True)
df
# Out:
#                  PID  Street number Street name  \
# 0          100001000          104.0      PUTNAM
# 1          100002000          197.0   LEXINGTON
# 2          100003000            NaN   LEXINGTON
# 3          100004000          201.0    BERKELEY
# 4                             203.0    BERKELEY
# 5          100006000          207.0    BERKELEY
# 6          100007000            NaN  WASHINGTON
# 7          100008000          213.0     TREMONT
# 8          100009000          215.0     TREMONT
#
#   Is the residence owner occupied Number of bedrooms NUM_BATH SQ_FT
# 0                               Y                  3        1  1000
# 1                               N                  3      1.5
# 2                               N                 -1        1   850
# 3                              12                  1      NaN   700
# 4                                                  3        2  1600
# 5                               Y                NAN        1   800
# 6                             NaN                  2   HURLEY   950
# 7                               Y                 --        1   NaN
# 8                               Y                 na        2  1800

# %% [markdown]
# ¿Cómo se clasifican los datos?
#
# * ST_NUM:
# * ST_NAME:
# * OWN_OCCUPIED:
# * NUM_BEDROOMS:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0           PID                      9 non-null      object
#  1   Street number                    7 non-null      float64
#  2   Street name                      9 non-null      object
#  3   Is the residence owner occupied  8 non-null      object
#  4   Number of bedrooms               9 non-null      object
#  5   NUM_BATH                         8 non-null      object
#  6   SQ_FT                            8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 576.0+ bytes

# %% [markdown]
# |           	| data classification 	|
# |----------:	|--------------------:	|
# | Street number |          object       |
# | Street name   |          float64       |
# | Is the residence owner occupied	|          object       |
# | Number of bedrooms 	|          object       |
# |  NUM_BATH	|          object       |
# |  SQ_FT        |          object       |

# %% [markdown]
# * Para cada columna, mostrar sus valores y una Serie booleana con `True` para aquellos valores que son null, combinar además `is_null()` y `sum()` para obtener un pequeño informe al respecto:

# %%
df.isnull().sum()
# Out:
#         PID                        0
# Street number                      2
# Street name                        0
# Is the residence owner occupied    1
# Number of bedrooms                 0
# NUM_BATH                           1
# SQ_FT                              1
# dtype: int64

# %% [markdown]
# * Para la columna `NUM_BEDROOMS`, determinar el conjunto de valores no válidos que *deberían reemplazarse* por `NaN`.

# %%
df_trabajo=df.copy()
df_trabajo
# Out:
#                  PID  Street number Street name  \
# 0          100001000          104.0      PUTNAM
# 1          100002000          197.0   LEXINGTON
# 2          100003000            NaN   LEXINGTON
# 3          100004000          201.0    BERKELEY
# 4                             203.0    BERKELEY
# 5          100006000          207.0    BERKELEY
# 6          100007000            NaN  WASHINGTON
# 7          100008000          213.0     TREMONT
# 8          100009000          215.0     TREMONT
#
#   Is the residence owner occupied Number of bedrooms NUM_BATH SQ_FT
# 0                               Y                  3        1  1000
# 1                               N                  3      1.5
# 2                               N                 -1        1   850
# 3                              12                  1      NaN   700
# 4                                                  3        2  1600
# 5                               Y                NAN        1   800
# 6                             NaN                  2   HURLEY   950
# 7                               Y                 --        1   NaN
# 8                               Y                 na        2  1800

# %% [markdown]
# * Usar el método `replace()` para convertir los mismos a `np.nan`

# %%
df_trabajo['Is the residence owner occupied'].replace('12',np.nan, inplace=True)
df_trabajo
# Out:
#                  PID  Street number Street name  \
# 0          100001000          104.0      PUTNAM
# 1          100002000          197.0   LEXINGTON
# 2          100003000            NaN   LEXINGTON
# 3          100004000          201.0    BERKELEY
# 4                             203.0    BERKELEY
# 5          100006000          207.0    BERKELEY
# 6          100007000            NaN  WASHINGTON
# 7          100008000          213.0     TREMONT
# 8          100009000          215.0     TREMONT
#
#   Is the residence owner occupied Number of bedrooms NUM_BATH SQ_FT
# 0                               Y                  3        1  1000
# 1                               N                  3      1.5
# 2                               N                 -1        1   850
# 3                             NaN                  1      NaN   700
# 4                                                  3        2  1600
# 5                               Y                NAN        1   800
# 6                             NaN                  2   HURLEY   950
# 7                               Y                 --        1   NaN
# 8                               Y                 na        2  1800

# %% [markdown]
# * Repetir el proceso con la columna `OWN_OCCUPIED`

# %% [markdown]
# ## fillna()
#
# Reemplaza NaN con un valor o método dados.

# %% [markdown]
# * Determinar un criterio y reemplazar los `NaN` de la columna

# %% [markdown]
# * Para el resto de las columnas:
#     * Determinar el conjunto de valores no válidos que deberían reemplazarse por NaN.
#     * Usar el método replace() para convertir los mismos a `np.nan`.
#     * Determinar un criterio y reemplazar los NaN de la columna.
